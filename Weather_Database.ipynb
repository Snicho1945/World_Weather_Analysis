# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        try:
            rain_hr = city_weather["rain"]["1h"]
        except KeyError:
            rain_hr = 0
        try:
            snow_hr = city_weather["snow"]["1h"]
        except KeyError:
            snow_hr = 0

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Rain(Inches)": rain_hr,
                          "Snow(Inches)": snow_hr,
                          "Current Weather": city_current,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | arrecife
# Processing Record 3 of Set 1 | pangai
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | pringsewu
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | maun
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | grindavik
# Processing Record 15 of Set 1 | asau
# Processing Record 16 of Set 1 | belogorsk
# Processing Record 17 of Set 1 | beidao
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | caravelas
# Processing Record 23 of Set 1 | san luis
# Processing Record 24 of Set 1 | vao
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | labuhan
# Processing Record 29 of Set 1 | hirara
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | namibe
# Processing Record 33 of Set 1 | eureka
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | achisay
# City not found. Skipping...
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | bassano
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | canutama
# Processing Record 41 of Set 1 | kavaratti
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | kaitangata
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | balkanabat
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | dutse
# Processing Record 50 of Set 1 | narasannapeta
# Processing Record 1 of Set 2 | fomboni
# Processing Record 2 of Set 2 | poum
# Processing Record 3 of Set 2 | ellensburg
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | bowen
# Processing Record 8 of Set 2 | havre-saint-pierre
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | den helder
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | gat
# Processing Record 13 of Set 2 | pantai remis
# Processing Record 14 of Set 2 | port hedland
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | inongo
# Processing Record 17 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 2 | acajutla
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | olinda
# Processing Record 22 of Set 2 | port hardy
# Processing Record 23 of Set 2 | ola
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | pangnirtung
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | kamariotissa
# Processing Record 32 of Set 2 | zalantun
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | morwell
# Processing Record 35 of Set 2 | port lincoln
# Processing Record 36 of Set 2 | paamiut
# Processing Record 37 of Set 2 | miles city
# Processing Record 38 of Set 2 | apaseo el alto
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | nishihara
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | walvis bay
# Processing Record 45 of Set 2 | hamilton
# Processing Record 46 of Set 2 | tual
# Processing Record 47 of Set 2 | araouane
# Processing Record 48 of Set 2 | katsuura
# Processing Record 49 of Set 2 | berlevag
# Processing Record 50 of Set 2 | doha
# Processing Record 1 of Set 3 | thinadhoo
# Processing Record 2 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 3 of Set 3 | beringovskiy
# Processing Record 4 of Set 3 | lakes entrance
# Processing Record 5 of Set 3 | kashi
# Processing Record 6 of Set 3 | calabozo
# Processing Record 7 of Set 3 | petrolina de goias
# Processing Record 8 of Set 3 | mangai
# Processing Record 9 of Set 3 | sandpoint
# Processing Record 10 of Set 3 | hovd
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 3 | mahibadhoo
# Processing Record 14 of Set 3 | mawlaik
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | tigil
# Processing Record 17 of Set 3 | baruun-urt
# Processing Record 18 of Set 3 | kangaatsiaq
# Processing Record 19 of Set 3 | poretskoye
# Processing Record 20 of Set 3 | solnechnyy
# Processing Record 21 of Set 3 | larsnes
# Processing Record 22 of Set 3 | cockburn town
# Processing Record 23 of Set 3 | kismayo
# Processing Record 24 of Set 3 | kahului
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | freetown
# Processing Record 28 of Set 3 | kirensk
# Processing Record 29 of Set 3 | sorong
# Processing Record 30 of Set 3 | nam som
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | port augusta
# Processing Record 33 of Set 3 | darhan
# Processing Record 34 of Set 3 | kudahuvadhoo
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | saint-joseph
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | amalapuram
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | castellammare del golfo
# Processing Record 42 of Set 3 | malibago
# Processing Record 43 of Set 3 | iqaluit
# Processing Record 44 of Set 3 | narsaq
# Processing Record 45 of Set 3 | codrington
# Processing Record 46 of Set 3 | ahumada
# City not found. Skipping...
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | bosaso
# Processing Record 49 of Set 3 | gap
# Processing Record 50 of Set 3 | mitu
# Processing Record 1 of Set 4 | agropoli
# Processing Record 2 of Set 4 | shahrud
# Processing Record 3 of Set 4 | visnes
# Processing Record 4 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | tessalit
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | diego de almagro
# Processing Record 10 of Set 4 | vallenar
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | bluff
# Processing Record 13 of Set 4 | sorland
# Processing Record 14 of Set 4 | lethem
# Processing Record 15 of Set 4 | half moon bay
# Processing Record 16 of Set 4 | verkhnevilyuysk
# Processing Record 17 of Set 4 | havelock
# Processing Record 18 of Set 4 | fort abbas
# Processing Record 19 of Set 4 | tromso
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 4 | port alfred
# Processing Record 23 of Set 4 | lichuan
# Processing Record 24 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 4 | lira
# Processing Record 26 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | san quintin
# Processing Record 30 of Set 4 | sidi ali
# Processing Record 31 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 4 | honiara
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | esperance
# Processing Record 36 of Set 4 | saint-pierre
# Processing Record 37 of Set 4 | mar del plata
# Processing Record 38 of Set 4 | luancheng
# Processing Record 39 of Set 4 | bontang
# Processing Record 40 of Set 4 | kamenka
# Processing Record 41 of Set 4 | chipping sodbury
# Processing Record 42 of Set 4 | hay river
# Processing Record 43 of Set 4 | sao gabriel da cachoeira
# Processing Record 44 of Set 4 | chichawatni
# Processing Record 45 of Set 4 | manhattan
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | nogliki
# Processing Record 49 of Set 4 | udachnyy
# Processing Record 50 of Set 4 | flinders
# Processing Record 1 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 5 | skjervoy
# Processing Record 3 of Set 5 | mareeba
# Processing Record 4 of Set 5 | meulaboh
# Processing Record 5 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | sonderso
# Processing Record 7 of Set 5 | verkhnyaya inta
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | arlit
# Processing Record 11 of Set 5 | akyab
# Processing Record 12 of Set 5 | seoul
# Processing Record 13 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 5 | maniitsoq
# Processing Record 15 of Set 5 | south lake tahoe
# Processing Record 16 of Set 5 | luderitz
# Processing Record 17 of Set 5 | oktyabrskoye
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | mpwapwa
# Processing Record 20 of Set 5 | taoudenni
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | fairbanks
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | torbay
# Processing Record 25 of Set 5 | lasa
# Processing Record 26 of Set 5 | el tigre
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 5 | plettenberg bay
# Processing Record 29 of Set 5 | bethel
# Processing Record 30 of Set 5 | martapura
# Processing Record 31 of Set 5 | kondoa
# Processing Record 32 of Set 5 | boa vista
# Processing Record 33 of Set 5 | karratha
# Processing Record 34 of Set 5 | metro
# Processing Record 35 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 5 | dabat
# Processing Record 37 of Set 5 | demirci
# Processing Record 38 of Set 5 | sharjah
# Processing Record 39 of Set 5 | sagana
# Processing Record 40 of Set 5 | harper
# Processing Record 41 of Set 5 | armeria
# Processing Record 42 of Set 5 | omboue
# Processing Record 43 of Set 5 | vostok
# Processing Record 44 of Set 5 | bubaque
# Processing Record 45 of Set 5 | kirakira
# Processing Record 46 of Set 5 | zlobin
# Processing Record 47 of Set 5 | susanville
# Processing Record 48 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 5 | belyy yar
# Processing Record 50 of Set 5 | ust-tsilma
# Processing Record 1 of Set 6 | duz
# City not found. Skipping...
# Processing Record 2 of Set 6 | bugama
# Processing Record 3 of Set 6 | port-gentil
# Processing Record 4 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 6 | aripuana
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | tura
# Processing Record 9 of Set 6 | warrnambool
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | okhotsk
# Processing Record 12 of Set 6 | dingle
# Processing Record 13 of Set 6 | pescia
# Processing Record 14 of Set 6 | san cristobal
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | kemin
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | san andres
# Processing Record 19 of Set 6 | sovetskaya
# Processing Record 20 of Set 6 | aberdeen
# Processing Record 21 of Set 6 | cidreira
# Processing Record 22 of Set 6 | east london
# Processing Record 23 of Set 6 | tambilil
# Processing Record 24 of Set 6 | sale
# Processing Record 25 of Set 6 | piranhas
# Processing Record 26 of Set 6 | carquefou
# Processing Record 27 of Set 6 | muzhi
# Processing Record 28 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 6 | matay
# Processing Record 31 of Set 6 | sogdiondon
# City not found. Skipping...
# Processing Record 32 of Set 6 | yining
# Processing Record 33 of Set 6 | praia da vitoria
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | ouadda
# Processing Record 36 of Set 6 | sao francisco
# Processing Record 37 of Set 6 | biltine
# Processing Record 38 of Set 6 | saint george
# Processing Record 39 of Set 6 | salamiyah
# Processing Record 40 of Set 6 | ust-ilimsk
# Processing Record 41 of Set 6 | fallon
# Processing Record 42 of Set 6 | qaanaaq
# Processing Record 43 of Set 6 | margate
# Processing Record 44 of Set 6 | tirat karmel
# Processing Record 45 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 6 | ust-ishim
# Processing Record 47 of Set 6 | novoseleznevo
# Processing Record 48 of Set 6 | dolores
# Processing Record 49 of Set 6 | leningradskiy
# Processing Record 50 of Set 6 | comodoro rivadavia
# Processing Record 1 of Set 7 | jacqueville
# Processing Record 2 of Set 7 | raposa
# Processing Record 3 of Set 7 | makakilo city
# Processing Record 4 of Set 7 | bani walid
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | husavik
# Processing Record 7 of Set 7 | tsiroanomandidy
# Processing Record 8 of Set 7 | palana
# Processing Record 9 of Set 7 | yarega
# Processing Record 10 of Set 7 | felipe carrillo puerto
# Processing Record 11 of Set 7 | paka
# Processing Record 12 of Set 7 | norman wells
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 16 of Set 7 | kavieng
# Processing Record 17 of Set 7 | garowe
# Processing Record 18 of Set 7 | whitehorse
# Processing Record 19 of Set 7 | baijiantan
# Processing Record 20 of Set 7 | barranca
# Processing Record 21 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 7 | krasnoselkup
# Processing Record 23 of Set 7 | sidney
# Processing Record 24 of Set 7 | itaituba
# Processing Record 25 of Set 7 | burica
# City not found. Skipping...
# Processing Record 26 of Set 7 | arinos
# Processing Record 27 of Set 7 | marsh harbour
# Processing Record 28 of Set 7 | aginskoye
# Processing Record 29 of Set 7 | fare
# Processing Record 30 of Set 7 | tuktoyaktuk
# Processing Record 31 of Set 7 | yerbogachen
# Processing Record 32 of Set 7 | skovorodino
# Processing Record 33 of Set 7 | praia
# Processing Record 34 of Set 7 | dalvik
# Processing Record 35 of Set 7 | vatne
# Processing Record 36 of Set 7 | prieska
# Processing Record 37 of Set 7 | uchiza
# Processing Record 38 of Set 7 | ji-parana
# City not found. Skipping...
# Processing Record 39 of Set 7 | upata
# Processing Record 40 of Set 7 | ahipara
# Processing Record 41 of Set 7 | puerto escondido
# Processing Record 42 of Set 7 | tagusao
# Processing Record 43 of Set 7 | avarua
# Processing Record 44 of Set 7 | rocha
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | shelburne
# Processing Record 47 of Set 7 | gadsden
# Processing Record 48 of Set 7 | urusha
# Processing Record 49 of Set 7 | ikeda
# Processing Record 50 of Set 7 | saquarema
# Processing Record 1 of Set 8 | viedma
# Processing Record 2 of Set 8 | innisfail
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | itarema
# Processing Record 5 of Set 8 | camopi
# Processing Record 6 of Set 8 | pevek
# Processing Record 7 of Set 8 | teguldet
# Processing Record 8 of Set 8 | lebanon
# Processing Record 9 of Set 8 | tautira
# Processing Record 10 of Set 8 | lazaro cardenas
# Processing Record 11 of Set 8 | kiunga
# Processing Record 12 of Set 8 | nizhniy tsasuchey
# Processing Record 13 of Set 8 | college
# Processing Record 14 of Set 8 | shakiso
# Processing Record 15 of Set 8 | saint-georges
# Processing Record 16 of Set 8 | laguna
# Processing Record 17 of Set 8 | linqing
# Processing Record 18 of Set 8 | sao miguel do araguaia
# Processing Record 19 of Set 8 | jesup
# Processing Record 20 of Set 8 | san patricio
# Processing Record 21 of Set 8 | parabel
# Processing Record 22 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 8 | jiuquan
# Processing Record 24 of Set 8 | loandjili
# Processing Record 25 of Set 8 | placido de castro
# Processing Record 26 of Set 8 | fuerte olimpo
# Processing Record 27 of Set 8 | balaguer
# Processing Record 28 of Set 8 | floro
# Processing Record 29 of Set 8 | miraflores
# Processing Record 30 of Set 8 | souillac
# Processing Record 31 of Set 8 | perrenjas
# City not found. Skipping...
# Processing Record 32 of Set 8 | bougouni
# Processing Record 33 of Set 8 | la palma
# Processing Record 34 of Set 8 | atbasar
# Processing Record 35 of Set 8 | bilibino
# Processing Record 36 of Set 8 | serenje
# Processing Record 37 of Set 8 | bengkulu
# Processing Record 38 of Set 8 | tuatapere
# Processing Record 39 of Set 8 | vardo
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | los palacios
# Processing Record 43 of Set 8 | nakhon phanom
# Processing Record 44 of Set 8 | melfi
# Processing Record 45 of Set 8 | nara
# Processing Record 46 of Set 8 | kloulklubed
# Processing Record 47 of Set 8 | avera
# Processing Record 48 of Set 8 | coquimbo
# Processing Record 49 of Set 8 | manokwari
# Processing Record 50 of Set 8 | hambantota
# Processing Record 1 of Set 9 | bagdarin
# Processing Record 2 of Set 9 | fiumicino
# Processing Record 3 of Set 9 | zhanaozen
# Processing Record 4 of Set 9 | san antero
# Processing Record 5 of Set 9 | garissa
# Processing Record 6 of Set 9 | lieksa
# Processing Record 7 of Set 9 | saurimo
# Processing Record 8 of Set 9 | dali
# Processing Record 9 of Set 9 | sumenep
# Processing Record 10 of Set 9 | kataysk
# Processing Record 11 of Set 9 | te anau
# Processing Record 12 of Set 9 | bereda
# Processing Record 13 of Set 9 | pano aqil
# Processing Record 14 of Set 9 | coihaique
# Processing Record 15 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 9 | san carlos de bariloche
# Processing Record 17 of Set 9 | palmer
# Processing Record 18 of Set 9 | beauchamps
# Processing Record 19 of Set 9 | mazara del vallo
# Processing Record 20 of Set 9 | zamora
# Processing Record 21 of Set 9 | huarmey
# Processing Record 22 of Set 9 | abu dhabi
# Processing Record 23 of Set 9 | wanning
# Processing Record 24 of Set 9 | fort nelson
# Processing Record 25 of Set 9 | talipparamba
# City not found. Skipping...
# Processing Record 26 of Set 9 | xiongshi
# City not found. Skipping...
# Processing Record 27 of Set 9 | vodnyy
# Processing Record 28 of Set 9 | cabedelo
# Processing Record 29 of Set 9 | inta
# Processing Record 30 of Set 9 | krasnaya gorka
# Processing Record 31 of Set 9 | korsakov
# Processing Record 32 of Set 9 | airai
# Processing Record 33 of Set 9 | stornoway
# Processing Record 34 of Set 9 | nome
# Processing Record 35 of Set 9 | port blair
# Processing Record 36 of Set 9 | birin
# Processing Record 37 of Set 9 | severnoye
# Processing Record 38 of Set 9 | mabaruma
# Processing Record 39 of Set 9 | shingu
# Processing Record 40 of Set 9 | menongue
# Processing Record 41 of Set 9 | yashkul
# Processing Record 42 of Set 9 | sur
# Processing Record 43 of Set 9 | gambela
# Processing Record 44 of Set 9 | jining
# Processing Record 45 of Set 9 | victoria
# Processing Record 46 of Set 9 | naze
# Processing Record 47 of Set 9 | muravlenko
# Processing Record 48 of Set 9 | stromness
# Processing Record 49 of Set 9 | annau
# Processing Record 50 of Set 9 | channel-port aux basques
# Processing Record 1 of Set 10 | caucaia
# Processing Record 2 of Set 10 | oussouye
# Processing Record 3 of Set 10 | kindu
# Processing Record 4 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 10 | anadyr
# Processing Record 6 of Set 10 | cap malheureux
# Processing Record 7 of Set 10 | maumere
# Processing Record 8 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 9 of Set 10 | bure
# Processing Record 10 of Set 10 | alofi
# Processing Record 11 of Set 10 | caconda
# Processing Record 12 of Set 10 | ulladulla
# Processing Record 13 of Set 10 | rudnyy
# Processing Record 14 of Set 10 | mogadishu
# Processing Record 15 of Set 10 | ushtobe
# Processing Record 16 of Set 10 | mahon
# Processing Record 17 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 10 | los llanos de aridane
# Processing Record 19 of Set 10 | putyatino
# Processing Record 20 of Set 10 | jos
# Processing Record 21 of Set 10 | labuan
# Processing Record 22 of Set 10 | mayumba
# Processing Record 23 of Set 10 | urubicha
# Processing Record 24 of Set 10 | tebingtinggi
# Processing Record 25 of Set 10 | homer
# Processing Record 26 of Set 10 | palmerston
# Processing Record 27 of Set 10 | colac
# Processing Record 28 of Set 10 | jipapad
# Processing Record 29 of Set 10 | inuvik
# Processing Record 30 of Set 10 | kruisfontein
# Processing Record 31 of Set 10 | thunder bay
# Processing Record 32 of Set 10 | mus
# Processing Record 33 of Set 10 | villarrica
# Processing Record 34 of Set 10 | isabela
# Processing Record 35 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 10 | pirajui
# Processing Record 38 of Set 10 | tabou
# Processing Record 39 of Set 10 | dunedin
# Processing Record 40 of Set 10 | seymchan
# Processing Record 41 of Set 10 | mount gambier
# Processing Record 42 of Set 10 | marawi
# Processing Record 43 of Set 10 | matara
# Processing Record 44 of Set 10 | rio grande
# Processing Record 45 of Set 10 | ambulu
# Processing Record 46 of Set 10 | bandrele
# Processing Record 47 of Set 10 | namatanai
# Processing Record 48 of Set 10 | digha
# Processing Record 49 of Set 10 | robstown
# Processing Record 50 of Set 10 | roald
# Processing Record 1 of Set 11 | alta floresta
# Processing Record 2 of Set 11 | odweyne
# Processing Record 3 of Set 11 | vityazevo
# Processing Record 4 of Set 11 | gamba
# Processing Record 5 of Set 11 | oranjemund
# Processing Record 6 of Set 11 | vesoul
# Processing Record 7 of Set 11 | bay roberts
# Processing Record 8 of Set 11 | chokwe
# Processing Record 9 of Set 11 | halifax
# Processing Record 10 of Set 11 | koroni
# Processing Record 11 of Set 11 | japura
# Processing Record 12 of Set 11 | henderson
# Processing Record 13 of Set 11 | bjornevatn
# Processing Record 14 of Set 11 | bilma
# Processing Record 15 of Set 11 | kotelnich
# Processing Record 16 of Set 11 | corner brook
# Processing Record 17 of Set 11 | demba
# Processing Record 18 of Set 11 | marica
# Processing Record 19 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 20 of Set 11 | deputatskiy
# Processing Record 21 of Set 11 | plattsburgh
# Processing Record 22 of Set 11 | perehonivka
# Processing Record 23 of Set 11 | cabano
# Processing Record 24 of Set 11 | ban nahin
# Processing Record 25 of Set 11 | ljaskovec
# City not found. Skipping...
# Processing Record 26 of Set 11 | si sa ket
# Processing Record 27 of Set 11 | malibu
# Processing Record 28 of Set 11 | palauig
# Processing Record 29 of Set 11 | kralendijk
# Processing Record 30 of Set 11 | szczecinek
# Processing Record 31 of Set 11 | ratnagiri
# Processing Record 32 of Set 11 | goderich
# Processing Record 33 of Set 11 | olafsvik
# Processing Record 34 of Set 11 | faanui
# Processing Record 35 of Set 11 | brownwood
# Processing Record 36 of Set 11 | muisne
# Processing Record 37 of Set 11 | malyn
# Processing Record 38 of Set 11 | bandarbeyla
# Processing Record 39 of Set 11 | nagod
# Processing Record 40 of Set 11 | chumikan
# Processing Record 41 of Set 11 | bathurst
# Processing Record 42 of Set 11 | tomigusuku
# Processing Record 43 of Set 11 | vila franca do campo
# Processing Record 44 of Set 11 | westport
# Processing Record 45 of Set 11 | sisimiut
# Processing Record 46 of Set 11 | prince rupert
# Processing Record 47 of Set 11 | beatrice
# Processing Record 48 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 50 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 12 | miandrivazo
# Processing Record 2 of Set 12 | lokoja
# Processing Record 3 of Set 12 | awjilah
# Processing Record 4 of Set 12 | mecca
# Processing Record 5 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 12 | blois
# Processing Record 7 of Set 12 | portland
# Processing Record 8 of Set 12 | jalpan
# Processing Record 9 of Set 12 | rock sound
# Processing Record 10 of Set 12 | kinanah
# City not found. Skipping...
# Processing Record 11 of Set 12 | saint-francois
# Processing Record 12 of Set 12 | qurbus
# Processing Record 13 of Set 12 | wanaka
# Processing Record 14 of Set 12 | strzelce krajenskie
# Processing Record 15 of Set 12 | kristiinankaupunki
# Processing Record 16 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 17 of Set 12 | kibaha
# Processing Record 18 of Set 12 | kango
# Processing Record 19 of Set 12 | pochutla
# Processing Record 20 of Set 12 | sao filipe
# Processing Record 21 of Set 12 | leiyang
# Processing Record 22 of Set 12 | borovoy
# Processing Record 23 of Set 12 | lodja
# Processing Record 24 of Set 12 | constitucion
# Processing Record 25 of Set 12 | escanaba
# Processing Record 26 of Set 12 | aykhal
# Processing Record 27 of Set 12 | mugan
# Processing Record 28 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 30 of Set 12 | juneau
# Processing Record 31 of Set 12 | soma
# Processing Record 32 of Set 12 | lakatoro
# Processing Record 33 of Set 12 | olga
# Processing Record 34 of Set 12 | nenton
# Processing Record 35 of Set 12 | alyangula
# Processing Record 36 of Set 12 | moose factory
# Processing Record 37 of Set 12 | yalchiki
# City not found. Skipping...
# Processing Record 38 of Set 12 | ust-nera
# Processing Record 39 of Set 12 | maldonado
# Processing Record 40 of Set 12 | cortez
# Processing Record 41 of Set 12 | ewa beach
# Processing Record 42 of Set 12 | phan thiet
# Processing Record 43 of Set 12 | bathsheba
# Processing Record 44 of Set 12 | coahuayana
# Processing Record 45 of Set 12 | neuquen
# Processing Record 46 of Set 12 | shushenskoye
# Processing Record 47 of Set 12 | strelka
# Processing Record 48 of Set 12 | basco
# Processing Record 49 of Set 12 | ipixuna
# Processing Record 50 of Set 12 | karaikkudi
# Processing Record 1 of Set 13 | trat
# Processing Record 2 of Set 13 | san marco in lamis
# Processing Record 3 of Set 13 | skibbereen
# Processing Record 4 of Set 13 | cayenne
# Processing Record 5 of Set 13 | athens
# Processing Record 6 of Set 13 | verkhoyansk
# Processing Record 7 of Set 13 | saint-louis
# Processing Record 8 of Set 13 | tahta
# Processing Record 9 of Set 13 | shimoda
# Processing Record 10 of Set 13 | ciudad bolivar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  New Norfolk -42.78  147.06      52.0        82           0        1.01
# 1     Arrecife  28.96  -13.55      69.8        83           1       17.22
# 2       Pangai -19.80 -174.35      75.2        78          75       18.34
# 3       Hobart -42.88  147.33      52.0        66          75        5.82
# 4   Nikolskoye  59.70   30.79      57.0        87           1        1.68
#
#   Country  Rain(Inches)  Snow(Inches) Current Weather                 Date
# 0      AU           0.0             0       clear sky  2020-07-13 02:53:46
# 1      ES           0.0             0       clear sky  2020-07-13 02:52:51
# 2      TO           0.0             0   broken clouds  2020-07-13 02:53:46
# 3      AU           0.0             0   broken clouds  2020-07-13 02:50:33
# 4      RU           0.0             0             fog  2020-07-13 02:53:46

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Current Weather", "Rain(Inches)","Snow(Inches)", "Wind Speed"]

# %%
Weather_database = city_data_df[new_column_order]
Weather_database.head()
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0  New Norfolk      AU  2020-07-13 02:53:46 -42.78  147.06      52.0
# 1     Arrecife      ES  2020-07-13 02:52:51  28.96  -13.55      69.8
# 2       Pangai      TO  2020-07-13 02:53:46 -19.80 -174.35      75.2
# 3       Hobart      AU  2020-07-13 02:50:33 -42.88  147.33      52.0
# 4   Nikolskoye      RU  2020-07-13 02:53:46  59.70   30.79      57.0
#
#    Humidity  Cloudiness Current Weather  Rain(Inches)  Snow(Inches)  \
# 0        82           0       clear sky           0.0             0
# 1        83           1       clear sky           0.0             0
# 2        78          75   broken clouds           0.0             0
# 3        66          75   broken clouds           0.0             0
# 4        87           1             fog           0.0             0
#
#    Wind Speed
# 0        1.01
# 1       17.22
# 2       18.34
# 3        5.82
# 4        1.68

# %%
# Create the output file (CSV).
output_data_file = "Weather_Data.csv"
# Export the City_Data into a CSV.
Weather_database.to_csv(output_data_file, index_label="City_ID")
